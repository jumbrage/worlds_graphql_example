# %% [markdown]
# # GraphQL API Exploration
# This notebook demonstrates how to interact with a GraphQL API using Python. We will break down the code into sections and explain each part.

# %% [markdown]
# ## Import Libraries
# First, we need to import the necessary libraries: `requests` for making HTTP requests and `json` for handling JSON data.

# %%
import requests
import json

# %% [markdown]
# ## Define the GraphQL Endpoint
# Next, we specify the URL of the GraphQL endpoint to which we will send our queries.

# %%
# Define the GraphQL endpoint
endpoint = ''

# %% [markdown]
# ## Define the Headers
# We need to include authentication tokens in our headers. Replace `'your-token-id'` and `'your-token-value'` with your actual tokens.

# %%
# Define the headers with x-token-id and x-token-value
headers = {
    'Content-Type': 'application/json',
    'x-token-id': '',
    'x-token-value': ''
}

# %% [markdown]
# ## Define the GraphQL Query
# This section contains the GraphQL query we want to execute. It retrieves track data filtered by time and device ID. We use placeholders for dynamic values such as `$first`, `$startTime`, `$endTime`, and `$after`.

# %%
# Define the GraphQL query
query = '''
query GetTracks($first: Int!, $startTime: DateTimeOffset!, $endTime: DateTimeOffset!, $after: String) {
  tracks(
    filter: {
      time: {
        between: [$startTime, $endTime]
      }
      deviceId:{
      eq: "4"
      }
    },
    first: $first,
    after: $after
  ) {
    edges {
      node {
        id
        tag
        startTime
        endTime
        properties{
        vector
        motion
        identity
        }
        metadata
      }
    }
    pageInfo {
      hasNextPage
      endCursor
    }
  }
}
'''

# %% [markdown]
# ## Define the Query Variables
# Set the values for the variables used in the query. This includes specifying the number of results to fetch (`first`), the start and end times (`startTime` and `endTime`), and the cursor for pagination (`after`).

# %%
# Define the variables for the query
variables = {
    'first': 300,
    'startTime': '2024-01-01T00:00:00Z',
    'endTime': '2024-08-10T00:00:00Z',
    'after': None  # Start with None, meaning the first page
}

# %% [markdown]
# ## Create the Payload
# Combine the query and variables into a payload that will be sent in the request body.

# %%
# Create the payload
payload = {
    'query': query,
    'variables': variables
}

# %% [markdown]
# ## Send the Request
# Finally, send the POST request to the GraphQL endpoint with the defined headers and payload. Handle the response and print the JSON data for inspection.

# %%
# Send the request
response = requests.post(endpoint, headers=headers, json=payload)
data = response.json()
print(json.dumps(data, indent=2))
# Out:
# {
#   "data": {
#     "tracks": {
#       "edges": [
#         {
#           "node": {
#             "id": "6533267a-e456-4e03-be18-39c3e9db43b4",
#             "tag": "flare",
#             "startTime": "2024-07-23T00:42:12.093Z",
#             "endTime": "2024-07-23T00:42:12.093Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "741bc5ba-0248-43dc-acd9-08454d22ef48",
#             "tag": "flare",
#             "startTime": "2024-07-23T03:45:14.885Z",
#             "endTime": "2024-07-23T03:45:14.885Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "85bb3954-10e8-468c-9f90-84d3b45c93c8",
#             "tag": "flare",
#             "startTime": "2024-07-23T05:11:00.627Z",
#             "endTime": "2024-07-23T05:11:00.627Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "bb6f945f-b758-4dc0-abc4-a0d778c45750",
#             "tag": "flare",
#             "startTime": "2024-07-23T09:06:36.652Z",
#             "endTime": "2024-07-23T09:06:36.652Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "9465a370-f3b8-4ec5-b00d-08b153ed047a",
#             "tag": "flare",
#             "startTime": "2024-07-23T09:13:43.261Z",
#             "endTime": "2024-07-23T09:13:43.261Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id":
z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "84336c6c-193a-43d6-9c6a-cece15509b4f",
#             "tag": "flare",
#             "startTime": "2024-08-09T12:15:35.738Z",
#             "endTime": "2024-08-09T12:15:35.738Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "a3a014be-1ce3-4380-97ce-49ae3ed401c3",
#             "tag": "flare",
#             "startTime": "2024-08-09T13:03:33.881Z",
#             "endTime": "2024-08-09T13:03:33.881Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "b8735245-357c-4880-9f3c-4dbce2b3abb2",
#             "tag": "flare",
#             "startTime": "2024-08-09T13:33:37.370Z",
#             "endTime": "2024-08-09T13:33:37.370Z",
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         },
#         {
#           "node": {
#             "id": "3ca4a3ce-1759-4b1d-9d6d-1135e599b3aa",
#             "tag": "flare",
#             "startTime": "2024-08-09T13:59:51.359Z",
#             "endTime": null,
#             "properties": null,
#             "metadata": {
#               "features": [],
#               "objectIdentifierName": "",
#               "objectIdentifierValue": "",
#               "objectIdentifierValueId": "",
#               "reidModelVersion": 0,
#               "objectAttributes": {}
#             }
#           }
#         }
#       ],
#       "pageInfo": {
#         "hasNextPage": true,
#         "endCursor": "eyJ0cmFja1N0YXJ0VGltZSI6IjIwMjQtMDgtMDlUMTM6NTk6NTEuMzU5WiIsImlkIjoiM2NhNGEzY2UtMTc1OS00YjFkLTlkNmQtMTEzNWU1OTliM2FhIn0="
#       }
#     }
#   }
# }

# %% [markdown]
# ## Load Results into Pandas DataFrame
# We can use Pandas to organize and analyze the data we retrieved from the API. First, we need to install Pandas if it's not already installed. Then, we will load the data into a DataFrame and perform basic data inspection.

# %%
import sys
print(sys.executable)
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.2.3/libexec/bin/python

# %%
import pandas

# %%
# Install pandas if necessary

import pandas as pd

# Extract the relevant data from the API response
tracks = data.get('data', {}).get('tracks', {}).get('edges', [])

# Flatten the data into a list of dictionaries
flattened_tracks = [edge['node'] for edge in tracks]

# Create a DataFrame
df = pd.DataFrame(flattened_tracks)

# Display the first few rows of the DataFrame
df.head()
# Out:
#                                      id    tag                 startTime  \
# 0  6533267a-e456-4e03-be18-39c3e9db43b4  flare  2024-07-23T00:42:12.093Z
# 1  741bc5ba-0248-43dc-acd9-08454d22ef48  flare  2024-07-23T03:45:14.885Z
# 2  85bb3954-10e8-468c-9f90-84d3b45c93c8  flare  2024-07-23T05:11:00.627Z
# 3  bb6f945f-b758-4dc0-abc4-a0d778c45750  flare  2024-07-23T09:06:36.652Z
# 4  9465a370-f3b8-4ec5-b00d-08b153ed047a  flare  2024-07-23T09:13:43.261Z
#
#                     endTime properties  \
# 0  2024-07-23T00:42:12.093Z       None
# 1  2024-07-23T03:45:14.885Z       None
# 2  2024-07-23T05:11:00.627Z       None
# 3  2024-07-23T09:06:36.652Z       None
# 4  2024-07-23T09:13:43.261Z       None
#
#                                             metadata
# 0  {'features': [], 'objectIdentifierName': '', '...
# 1  {'features': [], 'objectIdentifierName': '', '...
# 2  {'features': [], 'objectIdentifierName': '', '...
# 3  {'features': [], 'objectIdentifierName': '', '...
# 4  {'features': [], 'objectIdentifierName': '', '...

# %% [markdown]
# ## Summary
# In this notebook, we demonstrated how to interact with a GraphQL API using Python. We covered importing libraries, defining the GraphQL endpoint, setting up headers, writing queries, defining variables, creating the payload, sending the request, and loading the results into a Pandas DataFrame. You can now adapt this example to your own use cases and integrate it into your applications.
